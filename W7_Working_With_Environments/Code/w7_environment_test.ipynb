# %% [markdown]
# # Working with environments
#
# We have learned in the lecture that environments help us to organize python packages that we need for our analysis without breaking the system-wide python installation.
#
# ## Learning goals
#
# - Create a testing environment that contains the `xarray` package.
# - Activate the testing environment
# - Test the newly created environment

# %%
import xarray as xr

# %% [markdown]
# ## Testing: Xarray
#
# We have not yet talked about the `xarray` package. We will do so next week. For now just accept that `xarray` is a package similar to pandas. However unlike pandas, `xarray` is designed to work with multi-dimensional geospatial datasets including satellite data and climate model output.
#
# The code below loads a _netcdf_ file containing data from the [MODIS instruments](https://modis.gsfc.nasa.gov/) aboard NASA's Terra and Aqua satellite.
#
# If you have xarray installed, you should be able to successfully execute the code below.
#
# Look at the output below and try to make sense of it.

# %%
ds = xr.load_dataset('../Data/MOD13A3.061_1km_aid0001_latlon_2020_10km.nc')
ds
# Out:
# <xarray.Dataset> Size: 298MB
# Dimensions:                               (time: 12, lat: 357, lon: 790)
# Coordinates:
#   * time                                  (time) object 96B 2020-01-01 00:00:...
#   * lat                                   (lat) float64 3kB 50.81 ... 21.14
#   * lon                                   (lon) float64 6kB -128.9 ... -63.13
# Data variables:
#     crs                                   int8 1B -127
#     _1_km_monthly_EVI                     (time, lat, lon) float64 27MB nan ....
#     _1_km_monthly_MIR_reflectance         (time, lat, lon) float64 27MB nan ....
#     _1_km_monthly_NDVI                    (time, lat, lon) float64 27MB nan ....
#     _1_km_monthly_NIR_reflectance         (time, lat, lon) float64 27MB nan ....
#     _1_km_monthly_VI_Quality              (time, lat, lon) float64 27MB 5.12e...
#     _1_km_monthly_blue_reflectance        (time, lat, lon) float64 27MB nan ....
#     _1_km_monthly_pixel_reliability       (time, lat, lon) float64 27MB nan ....
#     _1_km_monthly_red_reflectance         (time, lat, lon) float64 27MB nan ....
#     _1_km_monthly_relative_azimuth_angle  (time, lat, lon) float64 27MB nan ....
#     _1_km_monthly_sun_zenith_angle        (time, lat, lon) float64 27MB nan ....
#     _1_km_monthly_view_zenith_angle       (time, lat, lon) float64 27MB nan ....
# Attributes:
#     title:        MOD13A3.061 for aid0001
#     Conventions:  CF-1.6
#     institution:  Land Processes Distributed Active Archive Center (LP DAAC)
#     source:       AppEEARS v3.48
#     references:   See README.md
#     history:      See README.md

# %% [markdown]
# ### Making a simple plot.
#
# Like *pandas*, *xarray* has a plotting capability. Here I am plotting a variable called `_1_km_monthly_EVI` for the first `.isel('time'=0)` that is in the loaded data.

# %%
ds['_1_km_monthly_EVI'].isel(time=0).plot()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Downloads/anaconda3/envs/ISAT_420_S26/lib/python3.13/site-packages/xarray/core/utils.py:1379, in attempt_import(module)
#    1378 try:
# -> 1379     return importlib.import_module(module)
#    1380 except ImportError as e:
#
# File ~/Downloads/anaconda3/envs/ISAT_420_S26/lib/python3.13/importlib/__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'matplotlib'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 ds['_1_km_monthly_EVI'].isel(time=0).plot()
#
# File ~/Downloads/anaconda3/envs/ISAT_420_S26/lib/python3.13/site-packages/xarray/plot/accessor.py:48, in DataArrayPlotAccessor.__call__(self, **kwargs)
#      46 @functools.wraps(dataarray_plot.plot, assigned=("__doc__", "__annotations__"))
#      47 def __call__(self, **kwargs) -> Any:
# ---> 48     return dataarray_plot.plot(self._da, **kwargs)
#
# File ~/Downloads/anaconda3/envs/ISAT_420_S26/lib/python3.13/site-packages/xarray/plot/dataarray_plot.py:316, in plot(darray, row, col, col_wrap, ax, hue, subplot_kws, **kwargs)
#     312     plotfunc = hist
#     314 kwargs["ax"] = ax
# --> 316 return plotfunc(darray, **kwargs)
#
# File ~/Downloads/anaconda3/envs/ISAT_420_S26/lib/python3.13/site-packages/xarray/plot/dataarray_plot.py:1582, in _plot2d.<locals>.newplotfunc(***failed resolving arguments***)
#    1578 yplt, ylab_extra = _resolve_intervals_2dplot(yvalnp, plotfunc.__name__)
#    1580 _ensure_plottable(xplt, yplt, zval)
# -> 1582 cmap_params, cbar_kwargs = _process_cmap_cbar_kwargs(
#    1583     plotfunc,
#    1584     zval.data,
#    1585     **locals(),
#    1586     _is_facetgrid=kwargs.pop("_is_facetgrid", False),
#    1587 )
#    1589 if "contour" in plotfunc.__name__:
#    1590     # extend is a keyword argument only for contour and contourf, but
#    1591     # passing it to the colorbar is sufficient for imshow and
#    1592     # pcolormesh
#    1593     kwargs["extend"] = cmap_params["extend"]
#
# File ~/Downloads/anaconda3/envs/ISAT_420_S26/lib/python3.13/site-packages/xarray/plot/utils.py:956, in _process_cmap_cbar_kwargs(func, data, cmap, colors, cbar_kwargs, levels, _is_facetgrid, **kwargs)
#     954 cmap_kwargs.update((a, kwargs[a]) for a in cmap_args if a in kwargs)
#     955 if not _is_facetgrid:
# --> 956     cmap_params = _determine_cmap_params(**cmap_kwargs)
#     957 else:
#     958     cmap_params = {
#     959         k: cmap_kwargs[k]
#     960         for k in ["vmin", "vmax", "cmap", "extend", "levels", "norm"]
#     961     }
#
# File ~/Downloads/anaconda3/envs/ISAT_420_S26/lib/python3.13/site-packages/xarray/plot/utils.py:190, in _determine_cmap_params(plot_data, vmin, vmax, cmap, center, robust, extend, levels, filled, norm, _is_facetgrid)
#     188     import matplotlib as mpl
#     189 else:
# --> 190     mpl = attempt_import("matplotlib")
#     192 if isinstance(levels, Iterable):
#     193     levels = sorted(levels)
#
# File ~/Downloads/anaconda3/envs/ISAT_420_S26/lib/python3.13/site-packages/xarray/core/utils.py:1381, in attempt_import(module)
#    1379     return importlib.import_module(module)
#    1380 except ImportError as e:
# -> 1381     raise ImportError(
#    1382         f"The {install_name} package is required {reason}"
#    1383         " but could not be imported."
#    1384         " Please install it with your package manager (e.g. conda or pip)."
#    1385     ) from e
#
# ImportError: The matplotlib package is required for plotting but could not be imported. Please install it with your package manager (e.g. conda or pip).

# %% [markdown]
# ## Final words
#
# This is all, if you can see the plot all is working well.
